# %% [markdown]
# <a href="https://colab.research.google.com/github/annamcd511/csRNA-seq_WalkThru/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/alexdobin/STAR/archive/2.7.11b.tar.gz
# !tar -xzf 2.7.11b.tar.gz
# !mv 2.7.11b.tar.gz STAR-2.7.11b
# %cd STAR-2.7.11b/source
# !make STAR
# Out:
# --2024-04-26 02:58:36--  https://github.com/alexdobin/STAR/archive/2.7.11b.tar.gz
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/alexdobin/STAR/tar.gz/refs/tags/2.7.11b [following]
# --2024-04-26 02:58:36--  https://codeload.github.com/alexdobin/STAR/tar.gz/refs/tags/2.7.11b
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘2.7.11b.tar.gz’
#
# 2.7.11b.tar.gz          [         <=>        ]  11.89M  7.07MB/s    in 1.7s
#
# 2024-04-26 02:58:38 (7.07 MB/s) - ‘2.7.11b.tar.gz’ saved [12466670]
#
# /content/STAR-2.7.11b/source
# xxd -i parametersDefault > parametersDefault.xxd
# make -C htslib lib-static
# ...

# %%
# !mkdir -p /content/HOMER
# %cd /content/HOMER
# !wget http://homer.ucsd.edu/homer/configureHomer.pl
# Out:
# /content/HOMER
# --2024-04-26 03:10:14--  http://homer.ucsd.edu/homer/configureHomer.pl
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27477 (27K) [application/x-perl]
# Saving to: ‘configureHomer.pl’
#
# configureHomer.pl   100%[===================>]  26.83K  --.-KB/s    in 0.03s
#
# 2024-04-26 03:10:14 (1000 KB/s) - ‘configureHomer.pl’ saved [27477/27477]

# %%
# %%perl configureHomer.pl -install
# Out:
# 	Current base directory for HOMER is /content/HOMER/./
#
# --2024-04-26 03:10:24--  http://homer.ucsd.edu/homer/update.txt
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17859 (17K) [text/plain]
# Saving to: ‘/content/HOMER/.//update.txt’
#
#      0K .......... .......                                    100%  653K=0.03s
#
# 2024-04-26 03:10:24 (653 KB/s) - ‘/content/HOMER/.//update.txt’ saved [17859/17859]
#
# 	Updating Settings...
# `wget -O 0.0340712769693745.tmp http://homer.ucsd.edu/homer/configureHomer.pl`;
# --2024-04-26 03:10:24--  http://homer.ucsd.edu/homer/configureHomer.pl
# Resolving homer.ucsd.edu (homer.ucsd.edu)... 169.228.63.226
# Connecting to homer.ucsd.edu (homer.ucsd.edu)|169.228.63.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27477 (27K) [application/x-perl]
# ...

# %%
# !echo $PATH
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %%
import os

# Define the additional path to add
additional_path = '/content/HOMER/bin/'

# Get the current value of the PATH variable
current_path = os.environ['PATH']

# Append the additional path to the current PATH
new_path = f"{current_path}:{additional_path}"

# Update the PATH environment variable
os.environ['PATH'] = new_path

# Print the updated PATH variable to verify the change
print(os.environ['PATH'])
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/HOMER/bin/

# %%
# %cd /content
# Out:
# /content

# %%
# !batchMakeTagDirectory.pl
# Out:
# Unrecognized escape \d passed through at /content/HOMER/bin/batchMakeTagDirectory.pl line 48.
#
# 	batchMakeTagDirectory.pl <key file> [makeTagDirectory options]...
#
# 	Key File: Tag delimited: <directory>TAB<alignment file>
# 		Duplicate directory name for multiple alignment files for same experiment
# 		Option: -cpu <#> : to run more than one at a time...
# 		Option: -r : TagDir names with "-r1", "-r2", etc. will also be merged

# %%
import os

# Define the additional path to add
additional_path = '/content/STAR-2.7.11b/source/'

# Get the current value of the PATH variable
current_path = os.environ['PATH']

# Append the additional path to the current PATH
new_path = f"{current_path}:{additional_path}"

# Update the PATH environment variable
os.environ['PATH'] = new_path

# Print the updated PATH variable to verify the change
print(os.environ['PATH'])
# Out:
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/HOMER/bin/:/content/STAR-2.7.11b/source/

# %%
# !apt-get install sra-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 45 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# ...

# %%
# !mkdir -p /content/SRA
# !mkdir -p /content/fastq/csRNA
# !mkdir -p /content/fastq/sRNA

# %cd /content/SRA
# !prefetch -v SRR24798023
# !fastq-dump --outdir /content/fastq/sRNA --split-files SRR24798023/SRR24798023.sra
# !mv /content/sRNA/SRR24798023_1.fastq /content/sRNA/Zea_mays_sRNA-r1.fastq
# Out:
# /content/SRA
#
# 2024-04-26T03:40:30 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2024-04-26T03:40:30 prefetch.2.11.3: 1) Downloading 'SRR24798023'...
# 2024-04-26T03:40:30 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2024-04-26T03:40:30 prefetch.2.11.3:  Downloading via HTTPS...
# 2024-04-26T03:40:46 prefetch.2.11.3:  HTTPS download succeed
# 2024-04-26T03:40:49 prefetch.2.11.3:  'SRR24798023' is valid
# 2024-04-26T03:40:49 prefetch.2.11.3: 1) 'SRR24798023' was downloaded successfully
# 2024-04-26T03:40:49 prefetch.2.11.3: 'SRR24798023' has 0 unresolved dependencies
# Read 13979577 spots for SRR24798023/SRR24798023.sra
# Written 13979577 spots for SRR24798023/SRR24798023.sra
# mv: cannot stat '/content/sRNA/SRR24798023_1.fastq': No such file or directory

# %%
os.chdir("/content/fastq/sRNA")
for file in os.listdir():
  if file.endswith("fastq"):
    # !homerTools trim -3 AGATCGGAAGAGCACACGTCT -mis 2 -minMatchLength 4 -min 20 {file}
# Out:
# 	Sequences will be trimmed at 3' end with adapter: AGATCGGAAGAGCACACGTCT
# 	Maximum number of mismatches in adapter sequence to consider 2
# 	Minimum number of matches to adapter sequence at the edge: 4
# 	Minimum length of sequence to keep 20
# 	Will parse file SRR24798023_1.fastq
# 	Trimmed output: 12607669 of 13979577 reads

# %%
# Out:
# SRR24798023_1.fastq  SRR24798023_1.fastq.lengths  SRR24798023_1.fastq.trimmed
